# %%
from functions import count_dementiated,describe_data,bar_chart,age_by_gender,cdr_by_gender,boxplots,plot_correlation_map,plot_confusion_metrix
import pandas as pd
import matplotlib.pyplot as plt


def feature_corr_analysis():
    df = pd.read_csv('oasis_longitudinal.csv')
    
   # print("NUMBER OF PATEINTS SUFFERING FROM DEMENTIA")
    count_dementiated(df)

   # print("NUMBER OF MALE AND FEMALE PATEINTS SUFFERING FROM DEMENTIA")
    bar_chart('M/F',df)
    plt.xlabel('Group',fontsize=13)
    plt.xticks(rotation=0,fontsize=12)
    plt.ylabel('Number of patients',fontsize=13)
    plt.legend()
    plt.title('Gender and Demented rate',fontsize=14)
    
    
   
    cdr_by_gender(df)
    print("CDR BY GENDER")
    
    age_by_gender(df)
    print("AGE BY CDR\n\n\n")
    
    boxplots(df)
    
    print("Interquartile Range of each feature")
    
feature_corr_analysis()
# Out:
# NUMBER OF PATIENTS HAVING DEMENTIA
#
#
#
# NUMBER OF MALE AND FEMALE PATEINTS SUFFERING FROM DEMENTIA
#               M   F
# Demented     40  38
# Nondemented  22  50
# CDR BY GENDER
# AGE BY CDR
#
#
#
# Interquartile Range of each feature
